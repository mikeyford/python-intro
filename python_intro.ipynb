# %%
import numpy

# %%
numpy.array([1,2])
# Out:
# array([1, 2])

# %%
import numpy as np

# %%
np.array([3,4])
# Out:
# array([3, 4])

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression

# %%
LinearRegression()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
from sklearn import linear_model

# %%
linear_model.LinearRegression()
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#from statsmodels import *

# %%
from sklearn.datasets import fetch_california_housing
cal_housing = fetch_california_housing()

# %%
cal = cal_housing.data

# %%
type(cal)
# Out:
# numpy.ndarray

# %%
cal
# Out:
# array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#           39.37      , -121.24      ]])

# %%
cal*cal
# Out:
# array([[6.93089550e+01, 1.68100000e+03, 4.87780297e+01, ...,
#         6.53086420e+00, 1.43489440e+03, 1.49401729e+04],
#        [6.89132420e+01, 4.41000000e+02, 3.89143543e+01, ...,
#         4.45143254e+00, 1.43337960e+03, 1.49377284e+04],
#        [5.26698548e+01, 2.70400000e+03, 6.86931916e+01, ...,
#         7.85266047e+00, 1.43262250e+03, 1.49426176e+04],
#        ...,
#        [2.89000000e+00, 2.89000000e+02, 2.70976751e+01, ...,
#         5.40857864e+00, 1.55472490e+03, 1.46942884e+04],
#        [3.48643584e+00, 3.24000000e+02, 2.84037077e+01, ...,
#         4.50801718e+00, 1.55472490e+03, 1.47185424e+04],
#        [5.70540996e+00, 2.56000000e+02, 2.76120506e+01, ...,
#         6.84859025e+00, 1.54999690e+03, 1.46991376e+04]])

# %%
cal.transpose()
# Out:
# array([[   8.3252    ,    8.3014    ,    7.2574    , ...,    1.7       ,
#            1.8672    ,    2.3886    ],
#        [  41.        ,   21.        ,   52.        , ...,   17.        ,
#           18.        ,   16.        ],
#        [   6.98412698,    6.23813708,    8.28813559, ...,    5.20554273,
#            5.32951289,    5.25471698],
#        ...,
#        [   2.55555556,    2.10984183,    2.80225989, ...,    2.3256351 ,
#            2.12320917,    2.61698113],
#        [  37.88      ,   37.86      ,   37.85      , ...,   39.43      ,
#           39.43      ,   39.37      ],
#        [-122.23      , -122.22      , -122.24      , ..., -121.22      ,
#         -121.32      , -121.24      ]])

# %%
np.transpose(cal)
# Out:
# array([[   8.3252    ,    8.3014    ,    7.2574    , ...,    1.7       ,
#            1.8672    ,    2.3886    ],
#        [  41.        ,   21.        ,   52.        , ...,   17.        ,
#           18.        ,   16.        ],
#        [   6.98412698,    6.23813708,    8.28813559, ...,    5.20554273,
#            5.32951289,    5.25471698],
#        ...,
#        [   2.55555556,    2.10984183,    2.80225989, ...,    2.3256351 ,
#            2.12320917,    2.61698113],
#        [  37.88      ,   37.86      ,   37.85      , ...,   39.43      ,
#           39.43      ,   39.37      ],
#        [-122.23      , -122.22      , -122.24      , ..., -121.22      ,
#         -121.32      , -121.24      ]])

# %%
cal[0,0]
# Out:
# 8.3252

# %%
type(cal)
# Out:
# numpy.ndarray

# %%
df = pd.DataFrame(cal)

# %%
df.head(n=20)
# Out:
#          0     1         2         3       4         5      6       7
# 0   8.3252  41.0  6.984127  1.023810   322.0  2.555556  37.88 -122.23
# 1   8.3014  21.0  6.238137  0.971880  2401.0  2.109842  37.86 -122.22
#        DOLS Issue?                Information Given Description  \
# 140050           N                                          NaN
# 151685         NaN                                          NaN
# 67380            N                                          NaN
# 71484          NaN                                          NaN
# 75917            N                                          NaN
# 144910         NaN                                          NaN
# 188210         NaN                                          NaN
# 153838         NaN                                          NaN
# 91026            N                                          NaN
# 66001            N  No Further Action from Contact (NFAContact)
#
#        Route of Access Description Nurse Setting? Residential Setting?  \
# 140050                         NaN              N                    N
# 151685                         NaN              N                    N
# 67380                          NaN              N                    N
# 71484                          NaN              N                    N
# 75917                          NaN              N                    N
# 144910                         NaN              N                    N
# 188210                         NaN              N                    N
# 153838                         NaN              N                    N
# 91026                          NaN              N                    N
# 66001      Community / Other Route              N                    N
#
#        Community Setting?      Contact Type Description Contact Type Code  \
# 140050                  N        Any other Professional         OTHERPROF
# 151685                  N  A Professional on the system           IASPROF
# 67380                   N        Any other Professional         OTHERPROF
# 71484                   N              Any other Person          OTHERPER
# 75917                   N        Any other Professional         OTHERPROF
# 144910                  N              Any other Person          OTHERPER
# 188210                  N        Any other Professional         OTHERPROF
# 153838                  N        Any other Professional         OTHERPROF
# 91026                   N              Any other Person          OTHERPER
# 66001                   N              Any other Person          OTHERPER
#
#                                Contact Outcome Desc Contact Outcome Code  \
# 140050     Link to Existing Referral (LinkReferral)         LinkReferral
# 151685       Progress to New Referral (NewReferral)          NewReferral
# 67380      Link to Existing Referral (LinkReferral)         LinkReferral
# 71484      Link to Existing Referral (LinkReferral)         LinkReferral
# 75917      Link to Existing Referral (LinkReferral)         LinkReferral
# 144910  No Further Action from Contact (NFAContact)           NFAContact
# 188210     Link to Existing Referral (LinkReferral)         LinkReferral
# 153838       Progress to New Referral (NewReferral)          NewReferral
# 91026      Link to Existing Referral (LinkReferral)         LinkReferral
# 66001   No Further Action from Contact (NFAContact)           NFAContact
#
#        Contact Method Description Contact Method Code  \
# 140050      Letter/Fax/Form/Email                 004
# 151685                    Meeting                 007
# 67380       Letter/Fax/Form/Email                 004
# 71484              Telephone call                 003
# 75917         Electronic Referral                 009
# 144910      Letter/Fax/Form/Email                 004
# 188210      Letter/Fax/Form/Email                 004
# 153838                    Meeting                 007
# 91026              Telephone call                 003
# 66001       Letter/Fax/Form/Email                 004
#
#                     Contact Source Description Contact Source Code  \
# 140050                                Hospital                 105
# 151685                           Social Worker                 200
# 67380                                 Hospital                 105
# 71484   Extended Family/Household/Carer/Parent                 101
# 75917                                 Hospital                 105
# 144910                                      GP                 104
# 188210                                Hospital                 105
# 153838                               CPN/ CMHN                 119
# 91026   Extended Family/Household/Carer/Parent                 101
# 66001                                   Police                 107
#
#                          Other Contact Reason Description Contact Reason Code
# 140050                             Section 5 Notification                sec5
# 151685                       Advice & Information Request                 509
# 67380                              Section 5 Notification                sec5
# 71484              Section 2 - Initial Assessment Request                X525
# 75917                      Section 5 - Hospital Discharge            SECTION5
# 144910  Mental Health Assessment Request of Vulnerable...                 202
# 188210                             Section 5 Notification                sec5
# 153838  Mental Health Assessment Request of Vulnerable...                 202
# 91026                           OT Equipment Repair Query                oter
# 66001              Section 2 - Initial Assessment Request                X525
